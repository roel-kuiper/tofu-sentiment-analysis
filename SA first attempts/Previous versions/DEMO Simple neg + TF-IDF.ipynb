# %%
import pandas as pd
import numpy as np
import glob
import docx
import openpyxl
import time
import os
from stanfordnlp.server import CoreNLPClient
from sklearn.feature_extraction.text import TfidfVectorizer
from operator import itemgetter
from string import digits

# %%
def neg(bucket):
    if bucket < 4:
        return bucket + 4
    else:
        return bucket - 4
    
def remove_nan(l):
    return [x for x in l if not pd.isnull(x)]

def get_text(doc_names):
    documents = []
    titles = []
    remove_digits = str.maketrans('', '', digits)
    for i in range(len(doc_names)):
        doc_name = doc_names[i]
        paragraphs = docx.Document(doc_name).paragraphs
        par_text = [paragraph.text.replace('\xa0', ' ') for paragraph in paragraphs]
        text = par_text[0]
        titles.append(text)
        for i in range(1, len(par_text)):
            par = par_text[i]
            if par:
                text += ' ' + par
        documents.append(text.lower().translate(remove_digits))
    return titles, documents

def bin_of_words(filename):
    df = pd.read_excel(filename)
    return [sorted(list(set(remove_nan(df[col].values)))) for col in df.columns]

# %%
CoreNLP = "/home/roguehydra/Documents/Jaar 3/TOFU/SA/stanford-corenlp"
os.environ["CORENLP_HOME"] = CoreNLP
doc_names = sorted(glob.glob('/home/roguehydra/Documents/Jaar 3/TOFU/SA/Webpages/TRAIN/*.doc*'))
titles, documents = get_text(doc_names)
print("Amount of docs: {}\n".format(len(documents)))
begin = time.time()
ann_doc = []
# set up the client
with CoreNLPClient(annotators=['tokenize','ssplit','pos','depparse'], timeout=60000, memory='16G') as client:
    # annotate documents on the server
    for text in documents:
        ann_doc.append(client.annotate(text))
        
negations = []
for ann in ann_doc:
    negated=[]
    token_dict = {}
    for i in range(len(ann.sentence)):
        # get the sentence
        sentence = ann.sentence[i]

        # get the dependency parse of the sentence
        dependency_parse = sentence.basicDependencies

        #get a dictionary associating each token/node with its label
        for j in range(0, len(sentence.token)) :
            token_dict[sentence.token[j].tokenEndIndex] = sentence.token[j].word

        #take previous sentences into consideration
        offset = sentence.token[0].tokenBeginIndex        

        #get a list of the dependencies with the words they connect
        for item in dependency_parse.edge:
            dep = item.dep
            if dep == 'neg':
                source_node = item.source
                source_name = token_dict[offset + source_node]
                negated.append(source_name)
    negations.append(negated)
end = time.time()
print("\nElapsed time: {}s".format(round(end - begin,1)))
# Out:
# Amount of docs: 32
#
# Starting server with command: java -Xmx16G -cp /home/roguehydra/Documents/Jaar 3/TOFU/SA/stanford-corenlp/* edu.stanford.nlp.pipeline.StanfordCoreNLPServer -port 9000 -timeout 60000 -threads 5 -maxCharLength 100000 -quiet True -serverProperties corenlp_server-7c1f8506ec404d92.props -preload tokenize,ssplit,pos,depparse
#
# Elapsed time: 44.6s

# %% [markdown]
# 1: Dream
#
# 2: Economic
#
# 3: Health
#
# 4: Environment
#
# 5: Nightmare

# %%
bins_of_words = bin_of_words('BINS - version 2.xlsx')

# %%
word_matrix = np.empty((len(documents), len(bins_of_words)), dtype=object)

# %%
for i in range(len(documents)):
    document = documents[i]
    for j in range(len(bins_of_words)):
        if str(word_matrix[i][j]) == 'None':
            word_matrix[i][j] = []
        bucket = bins_of_words[j]
        for word in bucket:
            if word in document:
                for _ in range(document.count(word)):
                    tmp = word_matrix[i][j].copy()
                    tmp.append(word)
                    word_matrix[i][j] = tmp

# %%
rows = [0,4]
for i in range(len(negations)):
    negated = negations[i]
    for word in negated:
        
        for j in rows:
            
            if word in word_matrix[i][j]:
                tmp = word_matrix[i][j].copy()
                tmp.pop(tmp.index(word))
                word_matrix[i][j] = tmp
                
                j2 = neg(j)
                tmp2 = word_matrix[i][j2].copy()
                tmp2.append(word)
                word_matrix[i][j2] = tmp2 
                break

# %%
score_matrix = np.zeros((len(documents), len(bins_of_words)))

# %%
for i in range(len(documents)):
    for j in range(len(bins_of_words)):
        score_matrix[i][j] = len(word_matrix[i][j])

# %%
for i in range(len(documents)):
    print("Document {} \n\n{}\n".format(i+1, titles[i]))
    positive = score_matrix[i][0]
    negative = score_matrix[i][4]
    total_sentiment = positive - negative
    
    economic = score_matrix[i][1] 
    health = score_matrix[i][2] 
    environment = score_matrix[i][3]
    total_topic =  economic + health + environment
    if total_sentiment > 0:
        sen_score = total_sentiment/positive
        if sen_score > 0.2:
            judgement = 'positive'
        else:
            judgement = 'neutral (leaning towards positive)'
    elif total_sentiment < 0:
        sen_score = total_sentiment/negative
        if sen_score < -0.1:
            judgement = 'negative'
        else:
            judgement = 'neutral (leaning towards negative)'
    elif total_sentiment == 0:
        judgement = 'neutral'
        sen_score = 0
    
    print("Sentiment (score) : {}, ({})\n".format(judgement,round(sen_score,2)))
    print("Economic score    : {}".format(round(economic/total_topic,2)))
    print("Health score      : {}".format(round(health/total_topic,2)))
    print("Evironmental score: {}".format(round(environment/total_topic,2)))
    print("- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - ")
# Out:
# Document 1
#
# Accurately mixing oil and water.
#
# Sentiment (score) : positive, (0.79)
#
# Economic score    : 0.66
# Health score      : 0.11
# Evironmental score: 0.23
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Document 2
#
# Wind energy is a clean, renewable form of energy that has many pros. Learn more below.
#
# Sentiment (score) : positive, (1.0)
#
# Economic score    : 0.45
# Health score      : 0.08
# Evironmental score: 0.48
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Document 3
#
# Interior Letter Canceling Wind Project Notes High Value Area for Bighorn Sheep, Eagles
#
# Sentiment (score) : neutral (leaning towards positive), (0.19)
#
# Economic score    : 0.15
# Health score      : 0.17
# Evironmental score: 0.68
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Document 4
#
# Considerations for the Development of Shale Gas in the United Kingdom _ PSE _ Physicians, Scientists, and Engineers for Healthy Energy
#
# Sentiment (score) : positive, (0.59)
#
# Economic score    : 0.3
# Health score      : 0.19
# Evironmental score: 0.51
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Document 5
#
# Hydraulic Fracturing for Oil and Gas: Impacts from the Hydraulic Fracturing Water Cycle on Drinking Water Resources in the United States (Final Report)
#
# Sentiment (score) : negative, (-0.34)
#
# Economic score    : 0.21
# Health score      : 0.15
# Evironmental score: 0.64
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Document 6
#
# FDA’s Approach to Regulation of Nanotechnology Products
#
# Sentiment (score) : positive, (0.57)
#
# Economic score    : 0.75
# Health score      : 0.23
# Evironmental score: 0.02
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Document 7
#
# Food
#
# Sentiment (score) : positive, (0.49)
#
# Economic score    : 0.45
# Health score      : 0.46
# Evironmental score: 0.09
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Document 8
#
# Fracking - An Overview
#
# Sentiment (score) : negative, (-0.45)
#
# Economic score    : 0.18
# Health score      : 0.33
# Evironmental score: 0.49
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Document 9
#
# We have updated the map
#
# Sentiment (score) : negative, (-0.22)
#
# Economic score    : 0.26
# Health score      : 0.14
# Evironmental score: 0.6
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Document 10
#
# Indiana Communities fighting Big Wind's Onslaught.
#
# Sentiment (score) : positive, (0.22)
#
# Economic score    : 0.31
# Health score      : 0.18
# Evironmental score: 0.5
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Document 11
#
# Leader in wind turbine management and maintenance
#
# Sentiment (score) : neutral (leaning towards positive), (0.05)
#
# Economic score    : 0.24
# Health score      : 0.25
# Evironmental score: 0.51
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Document 12
#
# Marcellus Shale
#
# Sentiment (score) : positive, (0.25)
#
# Economic score    : 0.35
# Health score      : 0.18
# Evironmental score: 0.47
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Document 13
#
# Ministers E Molewa and N Pandor and Deputy Minister G Oliphant: launch of the Strategic Environmental Assessment of shale gas development
#
# Sentiment (score) : positive, (0.61)
#
# Economic score    : 0.37
# Health score      : 0.12
# Evironmental score: 0.51
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Document 14
#
# Nanotechnology in the food packaging industry
#
# Sentiment (score) : neutral (leaning towards positive), (0.07)
#
# Economic score    : 0.28
# Health score      : 0.63
# Evironmental score: 0.09
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Document 15
#
# Nanotechnology Programs at FDA
#
# Sentiment (score) : positive, (0.79)
#
# Economic score    : 0.9
# Health score      : 0.09
# Evironmental score: 0.01
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Document 16
#
# Northland Power - Technologies
#
# Sentiment (score) : positive, (0.72)
#
# Economic score    : 0.39
# Health score      : 0.09
# Evironmental score: 0.52
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Document 17
#
# Offshore wind energy
#
# Sentiment (score) : positive, (0.66)
#
# Economic score    : 0.22
# Health score      : 0.15
# Evironmental score: 0.63
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Document 18
#
# Offshore wind – Van Oord
#
# Sentiment (score) : positive, (0.81)
#
# Economic score    : 0.17
# Health score      : 0.09
# Evironmental score: 0.74
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Document 19
#
# Nanolok Technology
# For High Barrier Applications
#
# Sentiment (score) : positive, (0.8)
#
# Economic score    : 0.58
# Health score      : 0.16
# Evironmental score: 0.26
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Document 20
#
# Peer reviewed study exposes potentially hazardous nanoparticles in baby formula
#
# Sentiment (score) : neutral (leaning towards positive), (0.14)
#
# Economic score    : 0.18
# Health score      : 0.64
# Evironmental score: 0.18
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Document 21
#
# Potentially hazardous nanoparticles found in powdered baby formula
#
# Sentiment (score) : neutral (leaning towards positive), (0.02)
#
# Economic score    : 0.32
# Health score      : 0.54
# Evironmental score: 0.14
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Document 22
#
# Precipitated Calcium Carbonate
#
# Sentiment (score) : positive, (0.59)
#
# Economic score    : 0.32
# Health score      : 0.2
# Evironmental score: 0.48
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Document 23
#
# Shale gas: what are the effects on people and the environment?
#
# Sentiment (score) : neutral (leaning towards positive), (0.14)
#
# Economic score    : 0.28
# Health score      : 0.04
# Evironmental score: 0.68
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Document 24
#
# The Need for an SEA Vision, Mission and Objectives SEA Details
#
# Sentiment (score) : positive, (0.61)
#
# Economic score    : 0.42
# Health score      : 0.13
# Evironmental score: 0.46
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Document 25
#
# The Basics of wind energy
#
# Sentiment (score) : positive, (0.29)
#
# Economic score    : 0.25
# Health score      : 0.14
# Evironmental score: 0.62
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Document 26
#
# Tight and shale gas
#
# Sentiment (score) : positive, (0.61)
#
# Economic score    : 0.26
# Health score      : 0.14
# Evironmental score: 0.6
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Document 27
#
# Treasure karoo action group
#
# Sentiment (score) : neutral (leaning towards positive), (0.12)
#
# Economic score    : 0.26
# Health score      : 0.2
# Evironmental score: 0.54
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Document 28
#
# Unconventional Oil and Natural Gas Development
#
# Sentiment (score) : positive, (0.81)
#
# Economic score    : 0.29
# Health score      : 0.19
# Evironmental score: 0.52
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Document 29
#
# Wind – Department of Energy
#
# Sentiment (score) : positive, (0.92)
#
# Economic score    : 0.64
# Health score      : 0.03
# Evironmental score: 0.33
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Document 30
#
# Wind energy economic development and benefits
#
# Sentiment (score) : positive, (0.64)
#
# Economic score    : 0.48
# Health score      : 0.13
# Evironmental score: 0.39
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Document 31
#
# Wind energy on land
#
# Sentiment (score) : positive, (0.88)
#
# Economic score    : 0.1
# Health score      : 0.03
# Evironmental score: 0.87
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Document 32
#
# Wind power environmental benefits AWEA
#
# Sentiment (score) : neutral (leaning towards negative), (-0.08)
#
# Economic score    : 0.2
# Health score      : 0.13
# Evironmental score: 0.67
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# %%
vectorizer = TfidfVectorizer(use_idf=True, stop_words='english', ngram_range=(1,3), min_df=2)
x = vectorizer.fit_transform(documents)
tf_idf_scores = x.toarray()
words = vectorizer.get_feature_names()
all_words = [n for m in bins_of_words for n in m]

# %%
for i in range(len(tf_idf_scores)):
    print('Document {}\n'.format(i+1))
    document = tf_idf_scores[i]
    sug = []
    for j in range(len(document)):
        score = document[j]
        if score > 0:
            word = words[j]
            if word not in all_words:
                sug.append((score, word))

    if sug != []:
        sug.sort(key=itemgetter(0), reverse=True)
        for s, word in sug[-100:-90]:
            print(word)
    print('- - - - - - - - - - - - - - - -\n')
# Out:
# Document 1
#
# inside
# micrographs
# organs
# pushed
# reach
# researchers
# showed
# sizes
# slightly
# square
# - - - - - - - - - - - - - - - -
#
# Document 2
#
# - - - - - - - - - - - - - - - -
#
# Document 3
#
# older
# opposed
# park
# pending
# petition
# purpose
# received
# regional
# reviewed
# rights
# - - - - - - - - - - - - - - - -
#
# Document 4
#
# - - - - - - - - - - - - - - - -
#
# Document 5
#
# final report
# impacts
# activities
# united
# united states
# final
# fracturing activities
# fracturing oil
# hydraulic fracturing activities
# hydraulic fracturing oil
# - - - - - - - - - - - - - - - -
#
# Document 6
#
# reduce risk
# regulate
# regulatory oversight
# scientific knowledge
# share perspectives
# share perspectives information
# standing
# submit
# supports
# unintended
# - - - - - - - - - - - - - - - -
#
# Document 7
#
# establishment
# examples
# food additive
# food environment
# food example
# independent experts
# indicated
# investigate
# nanomaterial
# nanomaterials increasingly
# - - - - - - - - - - - - - - - -
#
# Document 8
#
# stages
# step
# taking
# team
# technique
# traditionally
# valley
# energy
# affected
# basin
# - - - - - - - - - - - - - - - -
#
# Document 9
#
# - - - - - - - - - - - - - - - -
#
# Document 10
#
# https www
# july
# lease
# limited
# living near
# mark
# meteorological
# new wind
# november
# opposition
# - - - - - - - - - - - - - - - -
#
# Document 11
#
# life
# offshore wind
# percent
# farms
# time
# wind farms
# years
# energy
# developed
# large
# - - - - - - - - - - - - - - - -
#
# Document 12
#
# - - - - - - - - - - - - - - - -
#
# Document 13
#
# exist
# fossil
# framework
# grounded
# harmful health
# identified
# identifies
# identify
# karoo
# leading
# - - - - - - - - - - - - - - - -
#
# Document 14
#
# food contact
# food contact materials
# food environment
# food example
# furthermore
# gas barrier
# indicate
# levels
# matrix
# metals
# - - - - - - - - - - - - - - - -
#
# Document 15
#
# drug
# drug administration
# drugs
# educational
# explore
# fda nanotechnology
# fda regulatory
# fda works
# focused science
# focused science based
# - - - - - - - - - - - - - - - -
#
# Document 16
#
# increases
# located
# mainly
# manner
# metres
# nacelle
# offshore wind energy
# onshore wind
# operate
# operates
# - - - - - - - - - - - - - - - -
#
# Document 17
#
# conducting outreach
# developers
# ecosystems
# electrical
# electrical grid
# electricity grid
# energy california
# energy development
# enormous
# funded
# - - - - - - - - - - - - - - - -
#
# Document 18
#
# offshore wind
# projects
# installation
# solutions
# - - - - - - - - - - - - - - - -
#
# Document 19
#
# - - - - - - - - - - - - - - - -
#
# Document 20
#
# threats
# tracey
# tracey woodruff
# tracey woodruff phd
# university california
# university california san
# unregulated unlabeled nanomaterials
# urging immediate
# urging immediate removal
# use materials
# - - - - - - - - - - - - - - - -
#
# Document 21
#
# tested including gerber
# tracey
# tracey woodruff
# tracey woodruff phd
# university california
# university california san
# unlabeled nanomaterials
# unregulated unlabeled
# unregulated unlabeled nanomaterials
# urging immediate
# - - - - - - - - - - - - - - - -
#
# Document 22
#
# nanometers
# narrower
# obtained
# ocean
# ocean floor
# packaged
# page
# polymeric
# products small
# rare
# - - - - - - - - - - - - - - - -
#
# Document 23
#
# - - - - - - - - - - - - - - - -
#
# Document 24
#
# scientific research
# sea shale
# sea shale gas
# serve
# services improve
# set
# sharing
# solutions
# south african context
# south african government
# - - - - - - - - - - - - - - - -
#
# Document 25
#
# divided
# electricity generated wind
# electricity grid
# erected
# face
# factors
# feet tall
# finally
# flows
# generate power
# - - - - - - - - - - - - - - - -
#
# Document 26
#
# concrete
# conventional
# costly
# deep
# dense
# fields produce
# hair
# homes
# hydrocarbon
# implemented
# - - - - - - - - - - - - - - - -
#
# Document 27
#
# environment harmful health
# environmental assessment shale
# expected
# fracture
# gas exploration
# gas south
# gas south africa
# guarantees
# high volume
# inclusive
# - - - - - - - - - - - - - - - -
#
# Document 28
#
# hydraulic fracturing oil
# interior
# june
# laboratory
# natural gas development
# natural gas production
# offers
# organizations
# outreach
# page
# - - - - - - - - - - - - - - - -
#
# Document 29
#
# - - - - - - - - - - - - - - - -
#
# Document 30
#
# areas
# low
# benefits wind
# family
# farmers
# new window wind
# window wind
# expand
# wind energy
# wind projects
# - - - - - - - - - - - - - - - -
#
# Document 31
#
# - - - - - - - - - - - - - - - -
#
# Document 32
#
# percent
# source
# uses
# farms
# significant
# wind farms
# generation
# year
# impacts
# air pollutants
# - - - - - - - - - - - - - - - -
