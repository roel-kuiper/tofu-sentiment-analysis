# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk import tokenize
import pandas as pd
import glob
import docx

# %%
def SentimentScore(paragraph, weight=1):
    sentences = []
    lines_list = tokenize.sent_tokenize(paragraph)
    sentences.extend(lines_list)
    sid = SentimentIntensityAnalyzer()
    sentiment = 0
    for sentence in sentences:
        ss = sid.polarity_scores(sentence)
        score = ss['compound']
        if score < 0:
            sentiment += score*weight
        else:
            sentiment += score
    return round(sentiment,2), round(sentiment/len(sentences),2)

def remove_nan(l):
    return [x for x in l if not pd.isnull(x)]

def get_text(doc_names):
    documents = []
    titles = []
    for i in range(len(doc_names)):
        doc_name = doc_names[i]
        paragraphs = docx.Document(doc_name).paragraphs
        par_text = [paragraph.text.replace('\xa0', ' ') for paragraph in paragraphs]
        text = par_text[0]
        titles.append(text)
        for i in range(1, len(par_text)):
            par = par_text[i]
            if par:
                text += ' ' + par
        documents.append(text)
    return titles, documents

def bin_of_words():
    df = pd.read_excel('Bin of words TOFU software.xlsx')
    return [remove_nan(df.D.to_list()), remove_nan(df.ECD.to_list()), remove_nan(df.HED.to_list()), \
            remove_nan(df.END.to_list()), remove_nan(df.N.to_list()), remove_nan(df.ECN.to_list()), \
            remove_nan(df.HEN.to_list()), remove_nan(df.ENN.to_list())]

# %%
bins_of_words = bin_of_words()
doc_names = sorted(glob.glob('Webpages/TRAIN/*.doc*'))
titles, documents = get_text(doc_names)

# %%
for i in range(len(documents)):
    print("Document {} \n\n{}\n".format(i+1, titles[i]))
    doc = documents[i]
    _, average_sen = SentimentScore(doc, weight=2.5)
#     print("Total sentiment: {}".format(total_sen))

    if average_sen > 0.1:
        judgement = 'positive'
    elif average_sen < -0.1:
        judgement = 'negative'
    elif average_sen == 0:
        judgement = 'neutral'
    elif average_sen < 0 and average_sen >= -0.1: 
        judgement = 'neutral (leaning towards negative)'
    else:
        judgement = 'neutral (leaning towards positive)'
    print("Sentiment (score): {}, ({})".format(judgement, average_sen))
    print("- - - - - - - - - - - - - - -")
# Out:
# Document 1
#
# Accurately mixing oil and water.
#
# Sentiment (score): positive, (0.19)
# - - - - - - - - - - - - - - -
# Document 2
#
# Wind energy is a clean, renewable form of energy that has many pros. Learn more below.
#
# Sentiment (score): positive, (0.32)
# - - - - - - - - - - - - - - -
# Document 3
#
# Interior Letter Canceling Wind Project Notes High Value Area for Bighorn Sheep, Eagles
#
# Sentiment (score): neutral (leaning towards positive), (0.02)
# - - - - - - - - - - - - - - -
# Document 4
#
# Considerations for the Development of Shale Gas in the United Kingdom _ PSE _ Physicians, Scientists, and Engineers for Healthy Energy
#
# Sentiment (score): positive, (0.25)
# - - - - - - - - - - - - - - -
# Document 5
#
# Hydraulic Fracturing for Oil and Gas: Impacts from the Hydraulic Fracturing Water Cycle on Drinking Water Resources in the United States (Final Report)
#
# Sentiment (score): neutral (leaning towards negative), (-0.01)
# - - - - - - - - - - - - - - -
# Document 6
#
# FDA’s Approach to Regulation of Nanotechnology Products
#
# Sentiment (score): positive, (0.19)
# - - - - - - - - - - - - - - -
# Document 7
#
# Food
#
# Sentiment (score): positive, (0.27)
# - - - - - - - - - - - - - - -
# Document 8
#
# Fracking - An Overview
#
# Sentiment (score): negative, (-0.31)
# - - - - - - - - - - - - - - -
# Document 9
#
# We have updated the map
#
# Sentiment (score): negative, (-0.32)
# - - - - - - - - - - - - - - -
# Document 10
#
# Indiana Communities fighting Big Wind's Onslaught.
#
# Sentiment (score): neutral (leaning towards positive), (0.01)
# - - - - - - - - - - - - - - -
# Document 11
#
# Leader in wind turbine management and maintenance
#
# Sentiment (score): neutral (leaning towards negative), (-0.09)
# - - - - - - - - - - - - - - -
# Document 12
#
# Marcellus Shale
#
# Sentiment (score): positive, (0.27)
# - - - - - - - - - - - - - - -
# Document 13
#
# Ministers E Molewa and N Pandor and Deputy Minister G Oliphant: launch of the Strategic Environmental Assessment of shale gas development
#
# Sentiment (score): positive, (0.25)
# - - - - - - - - - - - - - - -
# Document 14
#
# Nanotechnology in the food packaging industry
#
# Sentiment (score): neutral (leaning towards positive), (0.01)
# - - - - - - - - - - - - - - -
# Document 15
#
# Nanotechnology Programs at FDA
#
# Sentiment (score): positive, (0.31)
# - - - - - - - - - - - - - - -
# Document 16
#
# Northland Power - Technologies
#
# Sentiment (score): neutral (leaning towards positive), (0.08)
# - - - - - - - - - - - - - - -
# Document 17
#
# Offshore wind energy
#
# Sentiment (score): positive, (0.46)
# - - - - - - - - - - - - - - -
# Document 18
#
# Offshore wind – Van Oord
#
# Sentiment (score): positive, (0.43)
# - - - - - - - - - - - - - - -
# Document 19
#
# Nanolok Technology
# For High Barrier Applications
#
# Sentiment (score): neutral (leaning towards positive), (0.08)
# - - - - - - - - - - - - - - -
# Document 20
#
# Peer reviewed study exposes potentially hazardous nanoparticles in baby formula
#
# Sentiment (score): positive, (0.12)
# - - - - - - - - - - - - - - -
# Document 21
#
# Potentially hazardous nanoparticles found in powdered baby formula
#
# Sentiment (score): negative, (-0.22)
# - - - - - - - - - - - - - - -
# Document 22
#
# Precipitated Calcium Carbonate
#
# Sentiment (score): neutral, (0.0)
# - - - - - - - - - - - - - - -
# Document 23
#
# Shale gas: what are the effects on people and the environment?
#
# Sentiment (score): neutral (leaning towards negative), (-0.05)
# - - - - - - - - - - - - - - -
# Document 24
#
# The Need for an SEA Vision, Mission and Objectives SEA Details
#
# Sentiment (score): positive, (0.3)
# - - - - - - - - - - - - - - -
# Document 25
#
# The Basics of wind energy
#
# Sentiment (score): positive, (0.14)
# - - - - - - - - - - - - - - -
# Document 26
#
# Tight and shale gas
#
# Sentiment (score): positive, (0.25)
# - - - - - - - - - - - - - - -
# Document 27
#
# Treasure karoo action group
#
# Sentiment (score): neutral (leaning towards negative), (-0.09)
# - - - - - - - - - - - - - - -
# Document 28
#
# Unconventional Oil and Natural Gas Development
#
# Sentiment (score): positive, (0.53)
# - - - - - - - - - - - - - - -
# Document 29
#
# Wind – Department of Energy
#
# Sentiment (score): positive, (0.73)
# - - - - - - - - - - - - - - -
# Document 30
#
# Wind energy economic development and benefits
#
# Sentiment (score): neutral (leaning towards positive), (0.1)
# - - - - - - - - - - - - - - -
# Document 31
#
# Wind energy on land
#
# Sentiment (score): positive, (0.28)
# - - - - - - - - - - - - - - -
# Document 32
#
# Wind power environmental benefits AWEA
#
# Sentiment (score): neutral (leaning towards negative), (-0.06)
# - - - - - - - - - - - - - - -
